# %%
# %pip install nltk wordcloud

import wordcloud
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
# Out:
# Requirement already satisfied: nltk in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (3.8.1)
# Requirement already satisfied: wordcloud in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (1.9.6)
# Requirement already satisfied: click in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: tqdm in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: numpy>=1.19.3 in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from wordcloud) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=3 in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/karangautam/Desktop/ppro/venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('/Users/karangautam/Desktop/ppro/amazon/Electronics_sample_300k.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   reviewTime  300000 non-null  object
#  1   reviewText  299933 non-null  object
#  2   summary     299962 non-null  object
#  3   asin        300000 non-null  object
#  4   reviewerID  300000 non-null  object
#  5   overall     300000 non-null  float64
# dtypes: float64(1), object(5)
# memory usage: 13.7+ MB

# %%
df.duplicated().sum()
# Out:
# 227

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (299773, 6)

# %%
df['overall'].value_counts()
# Out:
# overall
# 5.0    185053
# 4.0     51925
# 1.0     27812
# 3.0     20991
# 2.0     13992
# Name: count, dtype: int64

# %%
def check(val):
    if val <= 2:
        return 'Negative'
    elif val == 3:
        return 'Neutral'
    else:
        return 'Positive'

# %%
df['sentiment'] = df['overall'].apply(check)

# %%
df.drop(columns='overall', axis=1, inplace=True)

# %%
df.shape
# Out:
# (299773, 6)

# %%
df.rename(columns={'reviewText': 'review_text', 'summary': 'review_summary', 'reviewerID': 'reviewer_id', 'asin': 'product_id', 'reviewTime': 'review_time'}, inplace=True)

# %%
df['review_time'] = pd.to_datetime(df['review_time'], format='%m %d, %Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299773 entries, 0 to 299999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   review_time     299773 non-null  datetime64[ns]
#  1   review_text     299706 non-null  object
#  2   review_summary  299735 non-null  object
#  3   product_id      299773 non-null  object
#  4   reviewer_id     299773 non-null  object
#  5   sentiment       299773 non-null  object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 16.0+ MB
